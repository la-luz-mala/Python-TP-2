# %%
# Routing general
import sys
sys.path.append("../src")

# %%
# Ejercicio 1 - Cálculo de longitud de líneas, total de palabras y promedios
import ej_1

text = """Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way to do it.
Although that way may not be obvious at first unless you're Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good idea.
Namespaces are one honking great idea -- let's do more of those!"""

result = ej_1.ej1(text)
print(result)
# Out:
# Total de líneas: 19
# Total de palabras: 137
# Promedio de palabras por línea: 7.21
#
# Lineas por encima del promedio (7.21 palabras):
# - "Special cases aren't special enough to break the rules." (9 palabras)
# - "In the face of ambiguity, refuse the temptation to guess." (10 palabras)
# - "There should be one-- and preferably only one --obvious way to do it." (13 palabras)
# - "Although that way may not be obvious at first unless you're Dutch." (12 palabras)
# - "Although never is often better than *right* now." (8 palabras)
# - "If the implementation is hard to explain, it's a bad idea." (11 palabras)
# - "If the implementation is easy to explain, it may be a good idea." (13 palabras)
# - "Namespaces are one honking great idea -- let's do more of those!" (12 palabras)

# %%
# Ejercicio 2 - Cálculo de duración de una playlist, canción más corta y más larga
import ej_2

playlist = [
{"title": "Bohemian Rhapsody", "duration": "5:55"},
{"title": "Hotel California", "duration": "6:30"},
{"title": "Stairway to Heaven", "duration": "8:02"},
{"title": "Imagine", "duration": "3:07"},
{"title": "Smells Like Teen Spirit", "duration": "5:01"},
{"title": "Billie Jean", "duration": "4:54"},
{"title": "Hey Jude", "duration": "7:11"},
{"title": "Like a Rolling Stone", "duration": "6:13"},
]

result = ej_2.ej2(playlist)
print(result)
# Out:
# Duración total: 46m 53s
# Canción más larga: "Stairway to Heaven" (8:02)
# Canción más corta: "Imagine" (3:07)

# %%
# Ejercicio 3 - Ingresa palabras separadas por coma y espacio y se censurarán en una review (ej. "Torres, Marte, secreto")
import ej_3

review = """La película sigue a un grupo de astronautas que viajan a Marte
en una misión de rescate. El capitán Torres lidera al equipo a través
de tormentas solares y fallos en el sistema de navegación. Al llegar
a Marte descubren que la base está abandonada y los suministros
destruidos. Torres decide sacrificar la nave nodriza para salvar
al equipo y logran volver a la Tierra en una cápsula de emergencia.
El final revela que Torres sobrevivió gracias a un pasaje secreto."""

result = ej_3.ej3(review)
print(result)
# Out:
# La película sigue a un grupo de astronautas que viajan a *****
# en una misión de rescate. El capitán ****** lidera al equipo a través
# de tormentas solares y fallos en el sistema de navegación. Al llegar
# a ***** descubren que la base está abandonada y los suministros
# destruidos. ****** decide sacrificar la nave nodriza para salvar
# al equipo y logran volver a la Tierra en una cápsula de emergencia.
# El final revela que ****** sobrevivió gracias a un pasaje *******.

# %%
# Ejercicio 4 - Ingresa un email para que se valide
import ej_4

ej_4.ej4()
# Out:
# 'El email no es válido.'

# %%
# Ejercicio 5 - Ingresa un peso (sin "kg", número con o sin decimales) y un destino para obtener un precio
import ej_5

ej_5.ej5()
# Out:
# 'Costo de envío: 1000'

# %%
# Ejercicio 6 - Calcula las hashtags que más se repiten en una lista de Tweets (strings)
import ej_6

posts = [
"Arrancando el lunes con energía #Motivación #NuevaSemana",
"Terminé mi primer proyecto en Python #Python #Programación #OrgullosoDeMi",
"No puedo creer el final de la serie #SinSpoilers #SerieAdicta",
"Nuevo video en el canal sobre #InteligenciaArtificial y #Python",
"Entrenamiento de hoy completado #Fitness #Motivación #NoPainNoGain",
"Leyendo sobre #InteligenciaArtificial y el futuro del trabajo #Tecnología",
"Arranqué a estudiar #Programación por mi cuenta #Python #Autodidacta",
"Finde de lluvia, maratón de series #SerieAdicta #Relax",
"Workshop de #InteligenciaArtificial en la universidad #Tecnología #Programación"
]

result = ej_6.ej6(posts)
print(result)
# Out:
# Hashtags trending (más de una aparición):
# #Programación: 3
# #Python: 3
# #InteligenciaArtificial: 3
# #Motivación: 2
# #SerieAdicta: 2
# #Tecnología: 2

# %%
# Ejercicio 7 - Ingresa nombres de personas separados por coma para obtener resultados de un amigo invisible
import ej_7

result = ej_7.ej7()
print(result)
# Out:
# Sorteo de amigo invisible:
# Luis → Charly
# Charly → Alberto
# Alberto → Ana
# Ana → Luis

# %%
# Ejercicio 8 - Ingresa un mensaje y un desplazamiento para obtenerlo en cifrado César
import ej_8

result = ej_8.ej8()
print(result)
# Out:
# Mensaje cifrado: Ogpuclg
# Mensaje descifrado: Mensaje

# %%
# Ejercicio 9 - Depura y ordena una lista de estudiantes.
import ej_9

students = [
    {"name": " Ana García ", "grade": "8", "status": "aprobado"},
    {"name": "pedro lópez", "grade": "4", "status": "DESAPROBADO"},
    {"name": "MARÍA FERNÁNDEZ", "grade": "10", "status": "Aprobado"},
    {"name": "ana garcía", "grade": "9", "status": "aprobado"},
    {"name": None, "grade": "7", "status": "aprobado"},
    {"name": "Luis Martínez ", "grade": None, "status": "aprobado"},
    {"name": " carlos RUIZ", "grade": "6", "status": "aprobado"},
    {"name": "PEDRO LÓPEZ ", "grade": "3", "status": "desaprobado"},
    {"name": " ", "grade": "5", "status": "aprobado"},
    {"name": "María Fernández", "grade": "7", "status": "APROBADO"},
    {"name": "Sofía Torres", "grade": "9", "status": "Aprobado"},
    {"name": " sofía torres ", "grade": "8", "status": "aprobado"},
    {"name": "Carlos Ruiz", "grade": "6", "status": "APROBADO"},
    {"name": "Roberto Díaz", "grade": "absent", "status": "ausente"},
    {"name": "roberto díaz", "grade": "", "status": "Ausente"},
    {"name": None, "grade": None, "status": None},
    {"name": "Laura Méndez", "grade": "7", "status": "aprobado"},
    {"name": " laura méndez", "grade": "8", "status": "Aprobado"},
    {"name": "GABRIELA RÍOS", "grade": "5", "status": "aprobado"},
    {"name": "gabriela ríos ", "grade": "4", "status": "Desaprobado"},
]

result = ej_9.ej9(students)
print(result)
# Out:
# Registros limpios de alumnos:
# Nombre		Nota	Estado
# ------------------------------------------
# Ana García	9	Aprobado
# Carlos Ruiz	6	Aprobado
# Gabriela Ríos	5	Aprobado
# Laura Méndez	8	Aprobado
# María Fernández	10	Aprobado
# Pedro López	4	Desaprobado
# Sofía Torres	9	Aprobado
# Total de alumnos válidos: 7
